# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDA0101ENSkillsNetwork971-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# # Portfolio Project: Model Evaluation and Refinement - Cars Test Case
# **IBM Data Science Professional Certificate | Module 5: Model Evaluation and Refinement**
#
# ### 👨‍💻 Executive Summary
# This notebook shows the process required to evaluate models for car prices and determine which one is better to use based on statistical performance. With the use of cross validation scores, distribution plots, overfitting/underfitting analysis, R Squared, Ridge Regression, and Grid Search, we are able to generate different models, compare them, and evaluate to select the best option.
#
# ---
# *Original lab framework provided by IBM Skills Network. Technical implementation,
# statistical analysis, and model interpretation performed by [Roberto Castro/rcastro-ai](https://github.com/rcastro-ai)*

# %% [markdown]
# # Model Evaluation and Refinement
#
# Estimated time needed: **30** minutes
#
# ## Objectives
#
# After completing this lab you will be able to:
#
# *   Evaluate and refine prediction models

# %% [markdown]
# <h2>Table of Contents</h2>
# <ul>
#     <li><a href="https://#ref1">Model Evaluation </a></li>
#     <li><a href="https://#ref2">Over-fitting, Under-fitting and Model Selection </a></li>
#     <li><a href="https://#ref3">Ridge Regression </a></li>
#     <li><a href="https://#ref4">Grid Search</a></li>
# </ul>

# %% [markdown]
# If you are running the lab in your browser in Skills Network lab, so need to install the libraries using piplite.

# %%
# If you are running the lab in your browser, you we will install the libraries using ``piplite``
# Otherwise, these lines are commented out.

#import piplite
#await piplite.install(['pandas'])
#await piplite.install(['matplotlib'])
#await piplite.install(['scipy'])
#await piplite.install(['scikit-learn'])
#await piplite.install(['seaborn'])

# %% [markdown]
# If you run the lab locally using Anaconda, you can load the correct library and versions by uncommenting the following:

# %%
#If you run the lab locally using Anaconda, you can load the correct library and versions by uncommenting the following:

# Install specific version of libraries used in lab
#! mamba install pandas==1.3.3-y
#! mamba install numpy=1.21.2-y
#! mamba install sklearn=0.20.1-y

# %% [markdown]
# Import libraries:

# %%
# Importing needed libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# This function will download the dataset into your browser

# %%
# This function will download the dataset into your browser 

#from pyodide.http import pyfetch

#async def download(url, filename):
#    response = await pyfetch(url)
#    if response.status == 200:
#        with open(filename, "wb") as f:
#            f.write(await response.bytes())

# %% [markdown]
# This dataset was hosted on IBM Cloud object. Click <a href="https://cocl.us/DA101EN_object_storage?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDA0101ENSkillsNetwork20235326-2021-01-01">HERE</a> for free storage.
#
#
# you will need to download the dataset; using the 'download()' function.

# %%
# You will need to download the dataset; 

filepath = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/module_5_auto.csv'
#await download(filepath)

# %%
# File name for dataset

file_name = "module_5_auto.csv"

# %% [markdown]
# Load the data and store it in dataframe df:

# %% [markdown]
# > Note: This version of the lab is working on JupyterLite, which requires the dataset to be downloaded to the interface.While working on the downloaded version of this notebook on their local machines(Jupyter Anaconda), the learners can simply **skip the steps above,** and simply use the URL directly in the `pandas.read_csv()` function. You can uncomment and run the statements in the cell below.

# %%
# Loading the data into dataframe df - If file is locally available after downloading

#df = pd.read_csv(file_name, header=0) # file contains headers in row 0

# %%
# Using this code for local version (Anaconda, for example)

# Loading data into dataframe
df = pd.read_csv(filepath, header=0) # Dataset has headers in row 0

# %%
# Saving the original file locally 

#df.to_csv(file_name)

# %%
# Browsing first 5 rows of data

df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  symboling  normalized-losses         make  \
# 0             0           0          3                122  alfa-romero
# 1             1           1          3                122  alfa-romero
# 2             2           2          1                122  alfa-romero
# 3             3           3          2                164         audi
# 4             4           4          2                164         audi
#
#   aspiration num-of-doors   body-style drive-wheels engine-location  ...  \
# 0        std          two  convertible          rwd           front  ...
# 1        std          two  convertible          rwd           front  ...
# 2        std          two    hatchback          rwd           front  ...
# 3        std         four        sedan          fwd           front  ...
# 4        std         four        sedan          4wd           front  ...
#
#    compression-ratio  horsepower  peak-rpm  city-mpg  highway-mpg    price  \
# ...

# %% [markdown]
# First, let's only use numeric data:

# %%
# Getting only the numeric data

df = df._get_numeric_data()
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  symboling  normalized-losses  wheel-base  \
# 0             0           0          3                122        88.6
# 1             1           1          3                122        88.6
# 2             2           2          1                122        94.5
# 3             3           3          2                164        99.8
# 4             4           4          2                164        99.4
#
#      length     width  height  curb-weight  engine-size  ...  stroke  \
# 0  0.811148  0.890278    48.8         2548          130  ...    2.68
# 1  0.811148  0.890278    48.8         2548          130  ...    2.68
# 2  0.822681  0.909722    52.4         2823          152  ...    3.47
# 3  0.848630  0.919444    54.3         2337          109  ...    3.40
# 4  0.848630  0.922222    54.3         2824          136  ...    3.40
#
#    compression-ratio  horsepower  peak-rpm  city-mpg  highway-mpg    price  \
# ...

# %% [markdown]
# Let's remove the columns 'Unnamed:0.1' and 'Unnamed:0' since they do not provide any value to the models.

# %%
# Removing columns 'Unnamed:0.1' and 'Unnamed:0' as they do not provide value

df.drop(['Unnamed: 0.1', 'Unnamed: 0'], axis=1, inplace=True)

# Let's take a look at the updated DataFrame
df.head()
# Out:
#    symboling  normalized-losses  wheel-base    length     width  height  \
# 0          3                122        88.6  0.811148  0.890278    48.8
# 1          3                122        88.6  0.811148  0.890278    48.8
# 2          1                122        94.5  0.822681  0.909722    52.4
# 3          2                164        99.8  0.848630  0.919444    54.3
# 4          2                164        99.4  0.848630  0.922222    54.3
#
#    curb-weight  engine-size  bore  stroke  compression-ratio  horsepower  \
# 0         2548          130  3.47    2.68                9.0       111.0
# 1         2548          130  3.47    2.68                9.0       111.0
# 2         2823          152  2.68    3.47                9.0       154.0
# 3         2337          109  3.19    3.40               10.0       102.0
# 4         2824          136  3.19    3.40                8.0       115.0
#
#    peak-rpm  city-mpg  highway-mpg    price  city-L/100km  diesel  gas
# ...

# %% [markdown]
# Libraries for plotting:

# %%
# Importing libraries for plotting

# %pip install micropip
import micropip
await micropip.install(['ipywidgets'], keep_going=True)
import ipywidgets
from ipywidgets import interact, interactive, fixed, interact_manual
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# <h2>Functions for Plotting</h2>

# %%
# Defining distribution plot method

def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
    width = 12
    height = 10
    plt.figure(figsize=(width, height))
    
    ax1 = sns.kdeplot(RedFunction, color="r", label=RedName)
    ax2 = sns.kdeplot(BlueFunction, color="b", label=BlueName, ax=ax1)

    plt.title(Title)
    plt.xlabel('Price (in dollars)')
    plt.ylabel('Proportion of Cars')
    plt.legend()
    plt.show()
    plt.close()

# %%
# Defining plot method

def PollyPlot(xtrain, xtest, y_train, y_test, lr,poly_transform):
    width = 12
    height = 10
    plt.figure(figsize=(width, height))
    
    
    #training data 
    #testing data 
    # lr:  linear regression object 
    #poly_transform:  polynomial transformation object 
 
    xmax=max([xtrain.values.max(), xtest.values.max()])

    xmin=min([xtrain.values.min(), xtest.values.min()])

    x=np.arange(xmin, xmax, 0.1)


    plt.plot(xtrain, y_train, 'ro', label='Training Data')
    plt.plot(xtest, y_test, 'go', label='Test Data')
    plt.plot(x, lr.predict(poly_transform.fit_transform(x.reshape(-1, 1))), label='Predicted Function')
    plt.ylim([-10000, 60000])
    plt.ylabel('Price')
    plt.legend()

# %% [markdown]
# <h2 id="ref1">Part 1: Training and Testing</h2>
#
# <p>An important step in testing your model is to split your data into training and testing data. We will place the target data <b>price</b> in a separate dataframe <b>y_data</b>:</p>

# %%
# Creating serie y_datas to hold values for target variable price

y_data = df['price']

# %% [markdown]
# Drop price data in dataframe **x_data**:

# %%
# Create dataframe x_data without the column proce

x_data = df.drop('price',axis=1)

# %% [markdown]
# Now, we randomly split our data into training and testing data using the function <b>train_test_split</b>.

# %%
# Splitting the data into training set and testing set

# Importing needed library
from sklearn.model_selection import train_test_split

# Splitting the data
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.10, random_state=1) # 10% of the dataset will be for test data

print("Number of training samples:",x_train.shape[0])
print("Number of test samples :", x_test.shape[0])
# Out:
# Number of training samples: 180
# Number of test samples : 21

# %% [markdown]
# The <b>test_size</b> parameter sets the proportion of data that is split into the testing set. In the above, the testing set is 10% of the total dataset.

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1> Question  #1):</h1>
#
# <b>Use the function "train_test_split" to split up the dataset such that 40% of the data samples will be utilized for testing. Set the parameter "random_state" equal to zero. The output of the function should be the following:  "x_train1" , "x_test1", "y_train1" and  "y_test1".</b>
#
# </div>

# %%
# Splitting the data with 40% for test data and random state equal to zero

x_train1, x_test1, y_train1, y_test1 = train_test_split(x_data, y_data, test_size=0.40, random_state=0) # 40% of the dataset will be for test data

print("Number of training samples:",x_train1.shape[0])
print("Number of test samples :", x_test1.shape[0])
# Out:
# Number of training samples: 120
# Number of test samples : 81

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# x_train1, x_test1, y_train1, y_test1 = train_test_split(x_data, y_data, test_size=0.4, random_state=0)
# print("number of test samples :", x_test1.shape[0])
# print("number of training samples:",x_train1.shape[0])
# ```
#
# </details>

# %% [markdown]
# Let's import <b>LinearRegression</b> from the module <b>linear_model</b>.

# %%
# Importing needed library

from sklearn.linear_model import LinearRegression

# %% [markdown]
# We create a Linear Regression object:

# %%
# Creating linear regression object

lre = LinearRegression()

# %% [markdown]
# We fit the model using the feature "horsepower":

# %%
# Fitting the model using the feature 'horsepower'

lre.fit(x_train[['horsepower']], y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Let's calculate the R^2 on the test data:

# %%
# Getting R Squared on the test data

lre.score(x_test[['horsepower']], y_test)
# Out:
# 0.36358755750788285

# %% [markdown]
# We can see the R^2 is much smaller using the test data compared to the training data.

# %%
# Getting R Squared on the training data

lre.score(x_train[['horsepower']], y_train)
# Out:
# 0.6619724197515104

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1> Question  #2): </h1>
# <b>
# Find the R^2  on the test data using 40% of the dataset for testing.
# </b>
# </div>

# %%
# Getting R Squared for the test data that uses 40% of the dataset

# Splitting the data
x_train1, x_test1, y_train1, y_test1 = train_test_split(x_data, y_data, test_size=0.4, random_state=0)

# Creating linear regression object
lre1 = LinearRegression()

# Fitting the model using the feature 'horsepower'
lre1.fit(x_train1[['horsepower']], y_train1)

# Getting R Squared on the test data
lre1.score(x_test1[['horsepower']], y_test1)
# Out:
# 0.7139364665406973

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# x_train1, x_test1, y_train1, y_test1 = train_test_split(x_data, y_data, test_size=0.4, random_state=0)
# lre.fit(x_train1[['horsepower']],y_train1)
# lre.score(x_test1[['horsepower']],y_test1)
#
# ```
#
# </details>

# %% [markdown]
# Sometimes you do not have sufficient testing data; as a result, you may want to perform cross-validation. Let's go over several methods that you can use for cross-validation.

# %% [markdown]
# <h2>Cross-Validation Score</h2>

# %% [markdown]
# Let's import <b>cross_val_score</b> from the module <b>model_selection</b>.

# %%
# Importing needed library

from sklearn.model_selection import cross_val_score

# %% [markdown]
# We input the object, the feature ("horsepower"), and the target data (y_data). The parameter 'cv' determines the number of folds. In this case, it is 4.

# %%
# Calculating the cross validation score

Rcross = cross_val_score(lre, x_data[['horsepower']], y_data, cv=4)

# %% [markdown]
# The default scoring is R^2. Each element in the array has the average R^2 value for the fold:

# %%
# Showing the score

Rcross
# Out:
# array([0.7746232 , 0.51716687, 0.74785353, 0.04839605])

# %% [markdown]
# We can calculate the average and standard deviation of our estimate:

# %%
# Showing the mean and the standard deviation of the estimate using the scores from the cross validation

print("The mean of the folds are", Rcross.mean(), "and the standard deviation is" , Rcross.std())
# Out:
# The mean of the folds are 0.522009915042119 and the standard deviation is 0.29118394447560286

# %% [markdown]
# We can use negative squared error as a score by setting the parameter  'scoring' metric to 'neg_mean_squared_error'.

# %%
# Using negative squared error as a score

-1 * cross_val_score(lre,x_data[['horsepower']], y_data,cv=4,scoring='neg_mean_squared_error')
# Out:
# array([20254142.84026704, 43745493.26505169, 12539630.34014932,
#        17561927.7224759 ])

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1> Question  #3): </h1>
# <b>
# Calculate the average R^2 using two folds, then find the average R^2 for the second fold utilizing the "horsepower" feature:
# </b>
# </div>

# %%
# Calculating the mean cross validation score using two folds

Rcross1 = cross_val_score(lre, x_data[['horsepower']], y_data, cv=2)
mean_score = np.mean(Rcross1)
print('Mean R Square using two folds: ', mean_score)

# Average R Square for the second fold using the 'horsepower' feature
print('\nAverage R Square for the second fold: ', Rcross1[1])
# Out:
# Mean R Square using two folds:  0.5166761697127429
#
# Average R Square for the second fold:  0.44319612775502903

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# Rc=cross_val_score(lre,x_data[['horsepower']], y_data,cv=2)
# Rc.mean()
#
# ```
#
# </details>

# %% [markdown]
# You can also use the function 'cross_val_predict' to predict the output. The function splits up the data into the specified number of folds, with one fold for testing and the other folds are used for training. First, import the function:

# %%
# Importing needed library

from sklearn.model_selection import cross_val_predict

# %% [markdown]
# We input the object, the feature <b>"horsepower"</b>, and the target data <b>y_data</b>. The parameter 'cv' determines the number of folds. In this case, it is 4. We can produce an output:

# %%
# Generating predicted values

yhat = cross_val_predict(lre, x_data[['horsepower']], y_data, cv=4)
yhat[0:5]
# Out:
# array([14141.63807508, 14141.63807508, 20814.29423473, 12745.03562306,
#        14762.35027598])

# %% [markdown]
# <h2 id="ref2">Part 2: Overfitting, Underfitting and Model Selection</h2>
#
# <p>It turns out that the test data, sometimes referred to as the "out of sample data", is a much better measure of how well your model performs in the real world.  One reason for this is overfitting.
#
# Let's go over some examples. It turns out these differences are more apparent in Multiple Linear Regression and Polynomial Regression so we will explore overfitting in that context.</p>

# %% [markdown]
# Let's create Multiple Linear Regression objects and train the model using <b>'horsepower'</b>, <b>'curb-weight'</b>, <b>'engine-size'</b> and <b>'highway-mpg'</b> as features.

# %%
# Creating a linear regression object and fit the model using 4 features

lr = LinearRegression()
lr.fit(x_train[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']], y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Prediction using training data:

# %%
# Generating predicted values using training data

yhat_train = lr.predict(x_train[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']])
yhat_train[0:5]
print('')

# %% [markdown]
# Prediction using test data:

# %%
# Generating predicted values using test data

yhat_test = lr.predict(x_test[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']])
yhat_test[0:5]
print('')

# %% [markdown]
# Let's perform some model evaluation using our training and testing data separately. First, we import the seaborn and matplotlib library for plotting.

# %%
# Importing needed libraries

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# Let's examine the distribution of the predicted values of the training data.

# %%
# Examining the distribution of the predicted values of the training data

Title = 'Distribution Plot of Predicted Value Using Training Data vs. Training Data Distribution'
DistributionPlot(y_train, yhat_train, "Actual Values (Train)", "Predicted Values (Train)", Title)

# %% [markdown]
# Figure 1: Plot of predicted values using the training data compared to the actual values of the training data.

# %% [markdown]
# So far, the model seems to be doing well in learning from the training dataset. But what happens when the model encounters new data from the testing dataset? When the model generates new values from the test data, we see the distribution of the predicted values is much different from the actual target values.

# %%
# Examining the distribution of the predicted values of the test data

Title = 'Distribution Plot of Predicted Value Using Test Data vs. Data Distribution of Test Data'
DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",Title)

# %% [markdown]
# Figure 2: Plot of predicted value using the test data compared to the actual values of the test data.

# %% [markdown]
# <p>Comparing Figure 1 and Figure 2, it is evident that the distribution of the test data in Figure 1 is much better at fitting the data. This difference in Figure 2 is apparent in the range of 5000 to 15,000. This is where the shape of the distribution is extremely different. Let's see if polynomial regression also exhibits a drop in the prediction accuracy when analysing the test dataset.</p>

# %%
# Importing needed library

from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# <h4>Overfitting</h4>
# <p>Overfitting occurs when the model fits the noise, but not the underlying process. Therefore, when testing your model using the test set, your model does not perform as well since it is modelling noise, not the underlying process that generated the relationship. Let's create a degree 5 polynomial model.</p>

# %% [markdown]
# Let's use 55 percent of the data for training and the rest for testing:

# %%
# Splitting the data using 45% for testing

x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.45, random_state=0)

# %% [markdown]
# We will perform a degree 5 polynomial transformation on the feature <b>'horsepower'</b>.

# %%
# Using a 5th degree polynomial with feature 'horsepower'

pr = PolynomialFeatures(degree=5)
x_train_pr = pr.fit_transform(x_train[['horsepower']])
x_test_pr = pr.fit_transform(x_test[['horsepower']])
pr
# Out:
# PolynomialFeatures(degree=5)

# %% [markdown]
# Now, let's create a Linear Regression model "poly" and train it.

# %%
# Creating a linear regression model called 'poly'

poly = LinearRegression()
poly.fit(x_train_pr, y_train)

# Printing the coefficients
print(poly.coef_)
# Out:
# [ 0.00000000e+00 -1.13639644e+04  2.14487571e+02 -1.90423806e+00
#   8.07406119e-03 -1.31190821e-05]

# %% [markdown]
# We can see the output of our model using the method "predict." We assign the values to "yhat".

# %%
# Generating predicted values using the model with the test data

yhat = poly.predict(x_test_pr)
yhat[0:5]
# Out:
# array([ 6728.73642454,  7308.05941737, 12213.8089466 , 18893.13340882,
#        19995.81934008])

# %% [markdown]
# Let's take the first five predicted values and compare it to the actual targets.

# %%
# Comparing the first 5 instances of the generated predicted values and the actual target values

print("Predicted values:", yhat[0:4])
print("True values:", y_test[0:4].values)
print('')
# Out:
# Predicted values: [ 6728.73642454  7308.05941737 12213.8089466  18893.13340882]
# True values: [ 6295. 10698. 13860. 13499.]

# %% [markdown]
# We will use the function "PollyPlot" that we defined at the beginning of the lab to display the training data, testing data, and the predicted function.

# %%
# Generating a plot to show the training data, the test data, and the predicted function

PollyPlot(x_train['horsepower'], x_test['horsepower'], y_train, y_test, poly, pr)

# %% [markdown]
# Figure 3: A polynomial regression model where red dots represent training data, green dots represent test data, and the blue line represents the model prediction.

# %% [markdown]
# We see that the estimated function appears to track the data but around 200 horsepower, the function begins to diverge from the data points.

# %% [markdown]
# R^2 of the training data:

# %%
# Calculating R Square of the training data

poly.score(x_train_pr, y_train)
# Out:
# 0.5567716902116695

# %% [markdown]
# R^2 of the test data:

# %%
# Calculating R Square of the test data

poly.score(x_test_pr, y_test)
# Out:
# -29.871607311777137

# %% [markdown]
# We see the R^2 for the training data is 0.5567 while the R^2 on the test data was -29.87.  The lower the R^2, the worse the model. A negative R^2 is a sign of **overfitting**.

# %% [markdown]
# Let's see how the R^2 changes on the test data for different order polynomials and then plot the results:

# %%
# Testing the model for four different order ploynomials

Rsqu_test = []

order = [1, 2, 3, 4]
for n in order:
    pr = PolynomialFeatures(degree=n)
    
    x_train_pr = pr.fit_transform(x_train[['horsepower']])
    
    x_test_pr = pr.fit_transform(x_test[['horsepower']])    
    
    lr.fit(x_train_pr, y_train)
    
    Rsqu_test.append(lr.score(x_test_pr, y_test))

plt.plot(order, Rsqu_test)
plt.xlabel('order')
plt.ylabel('R^2')
plt.title('R^2 Using Test Data')
plt.text(3, 0.75, 'Maximum R^2 ')
# Out:
# Text(3, 0.75, 'Maximum R^2 ')

# %% [markdown]
# We see the R^2 gradually increases until an order three polynomial is used. Then, the R^2 dramatically decreases at an order four polynomial.

# %% [markdown]
# The following function will be used in the next section. Please run the cell below.

# %%
# Defining method to plot training data, test data, and predicted function

from IPython.display import display, clear_output
import matplotlib.pyplot as plt

def f(order, test_data):
    # This prevents the chart from getting 'stuck'
    clear_output(wait=True)
    
    plt.figure(figsize=(10, 6))
    x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=test_data, random_state=0)
    pr = PolynomialFeatures(degree=order)
    x_train_pr = pr.fit_transform(x_train[['horsepower']])
    x_test_pr = pr.fit_transform(x_test[['horsepower']])
    
    poly = LinearRegression()
    poly.fit(x_train_pr,y_train)
    
    # Plotting logic
    PollyPlot(x_train['horsepower'], x_test['horsepower'], y_train, y_test, poly,pr)
    plt.show()

# %% [markdown]
# The following interface allows you to experiment with different polynomial orders and different amounts of data.
#
# Note: Switched to manual interaction to avoid issues when refreshing the plot. Click on the "Run Interact" button after selecting the options with the sliders.

# %%
# Testing for different polynomial orders and different amounts of data

from ipywidgets import interact_manual

#interact(f, order=(0, 6, 1), test_data=(0.05, 0.95, 0.05))
interact_manual(f, order=(0, 6, 1), test_data=(0.05, 0.95, 0.05))
# Out:
# interactive(children=(IntSlider(value=3, description='order', max=6), FloatSlider(value=0.45, description='tes…
# <function __main__.f(order, test_data)>

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1> Question  #4a):</h1>
#
# <b>We can perform polynomial transformations with more than one feature. Create a "PolynomialFeatures" object "pr1" of degree two.</b>
#
# </div>

# %%
# Creating a polynomial features object of degree 2

pr1 = PolynomialFeatures(degree=2)

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# pr1=PolynomialFeatures(degree=2)
#
# ```
#
# </details>

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1> Question  #4b): </h1>
#
# <b>
#  Transform the training and testing samples for the features 'horsepower', 'curb-weight', 'engine-size' and 'highway-mpg'. Hint: use the method "fit_transform".</b>
# </div>

# %%
# Creating training and testing data for features 'horsepower', 'curb-weight', 'engine-size' and 'highway-mpg'

x_train_pr1 = pr1.fit_transform(x_train[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']])
x_test_pr1 = pr1.fit_transform(x_test[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']])
pr1
# Out:
# PolynomialFeatures()

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# x_train_pr1=pr1.fit_transform(x_train[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']])
#
# x_test_pr1=pr1.fit_transform(x_test[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']])
#
#
# ```
#
# </details>

# %% [markdown]
# <!-- The answer is below:
#
# x_train_pr1=pr.fit_transform(x_train[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']])
# x_test_pr1=pr.fit_transform(x_test[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']])
#
# -->

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1> Question  #4c): </h1>
# <b>
# How many dimensions does the new feature have? Hint: use the attribute "shape".
# </b>
# </div>

# %%
# Showing the number of dimensions of the new feature

x_train_pr1.shape # This shows that we have now 15 output features
# Out:
# (110, 15)

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# x_train_pr1.shape #there are now 15 features
#
#
# ```
#
# </details>

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1> Question  #4d): </h1>
#
# <b>
# Create a linear regression model "poly1". Train the object using the method "fit" using the polynomial features.</b>
# </div>

# %%
# Creating and training the regression model poly1

poly1 = LinearRegression()
poly1.fit(x_train_pr1, y_train)

# Printing the coefficients
print(poly1.coef_)
# Out:
# [ 0.00000000e+00 -3.51918127e+02  1.23113454e+01 -3.94566415e+02
#  -9.79801176e+02  1.68177587e-01  8.63770817e-02 -4.53938855e-01
#   5.62860300e+00 -6.02412699e-03  1.91126950e-01 -9.41078388e-02
#  -4.40193990e-01  1.24123998e+00  8.22981931e+00]

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# poly1=LinearRegression().fit(x_train_pr1,y_train)
#
#
# ```
#
# </details>

# %% [markdown]
#  <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1> Question  #4e): </h1>
# <b>Use the method  "predict" to predict an output on the polynomial features, then use the function "DistributionPlot" to display the distribution of the predicted test output vs. the actual test data.</b>
# </div>

# %%
# Generating predicted values and plotting the distribution of the predicted test data vs. the actual test data

yhat1 = poly1.predict(x_test_pr1)
yhat[0:5]

Title = 'Distribution Plot of Predicted Value Using Test Data vs. Actual Test Data Distribution'
DistributionPlot(y_test, yhat1, "Actual Values (Test)", "Predicted Values (Test)", Title)

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# yhat_test1=poly1.predict(x_test_pr1)
#
# Title='Distribution  Plot of  Predicted Value Using Test Data vs Data Distribution of Test Data'
#
# DistributionPlot(y_test, yhat_test1, "Actual Values (Test)", "Predicted Values (Test)", Title)
#
# ```
#
# </details>

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1> Question  #4f): </h1>
#
# <b>Using the distribution plot above, describe (in words) the two regions where the predicted prices are less accurate than the actual prices.</b>
#
# </div>

# %% [markdown]
# The chart shows that the model diverges from the actual function in two areas: Around the price of 10,000 (plus/minus 1,000) and then for prices above 28,000. Given this behavior, we conclude that the model is not a good fit.

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# #The predicted value is higher than actual value for cars where the price $10,000 range, conversely the predicted price is lower than the price cost in the $30,000 to $40,000 range. As such the model is not as accurate in these ranges.
#
# ```
#
# </details>

# %% [markdown]
# <h2 id="ref3">Part 3: Ridge Regression</h2>

# %% [markdown]
# In this section, we will review Ridge Regression and see how the parameter alpha changes the model. Just a note, here our test data will be used as validation data.

# %% [markdown]
# Let's perform a degree two polynomial transformation on our data.

# %%
# Performing a degree two polynomial transformation

pr = PolynomialFeatures(degree=2)
x_train_pr = pr.fit_transform(x_train[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg','normalized-losses','symboling']])
x_test_pr = pr.fit_transform(x_test[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg','normalized-losses','symboling']])

# %% [markdown]
# Let's import  <b>Ridge</b>  from the module <b>linear models</b>.

# %%
# Importing needed library

from sklearn.linear_model import Ridge

# %% [markdown]
# Let's create a Ridge regression object, setting the regularization parameter (alpha) to 0.1

# %%
# Creating a Ridge regression with alpha (regularization parameter) set to 0.1

RigeModel = Ridge(alpha=0.1)

# %% [markdown]
# Like regular regression, you can fit the model using the method <b>fit</b>.

# %%
# Fitting the model

RigeModel.fit(x_train_pr, y_train)
# Out:
# Ridge(alpha=0.1)

# %% [markdown]
# Similarly, you can obtain a prediction:

# %%
# Generating a prediction

yhat = RigeModel.predict(x_test_pr)

# %% [markdown]
# Let's compare the first five predicted samples to our test set:

# %%
# Comparing the first 5 values of the predicted values and the test data

print('predicted:', yhat[0:4])
print('test set :', y_test[0:4].values)
# Out:
# predicted: [ 6567.83081933  9597.97151399 20836.22326843 19347.69543463]
# test set : [ 6295. 10698. 13860. 13499.]

# %% [markdown]
# We select the value of alpha that minimizes the test error. To do so, we can use a for loop. We have also created a progress bar to see how many iterations we have completed so far.

# %%
# Obtaining the value of the scores for different values of alpha

from tqdm import tqdm

Rsqu_test = []
Rsqu_train = []
dummy1 = []
Alpha = 10 * np.array(range(0,1000))
pbar = tqdm(Alpha)

for alpha in pbar:
    RigeModel = Ridge(alpha=alpha) 
    RigeModel.fit(x_train_pr, y_train)
    test_score, train_score = RigeModel.score(x_test_pr, y_test), RigeModel.score(x_train_pr, y_train)
    
    pbar.set_postfix({"Test Score": test_score, "Train Score": train_score})

    Rsqu_test.append(test_score)
    Rsqu_train.append(train_score)
# Out:
# 100%|██████████| 1000/1000 [00:02<00:00, 416.01it/s, Test Score=0.564, Train Score=0.859]

# %% [markdown]
# We can plot out the value of R^2 for different alphas:

# %%
# Plotting the values of R Squared for different values of alpha

width = 12
height = 10
plt.figure(figsize=(width, height))

plt.plot(Alpha, Rsqu_test, label='validation data  ')
plt.plot(Alpha, Rsqu_train, 'r', label='training Data ')
plt.xlabel('alpha')
plt.ylabel('R^2')
plt.legend()

# %% [markdown]
# **Figure 4**: The blue line represents the R^2 of the validation data, and the red line represents the R^2 of the training data. The x-axis represents the different values of Alpha.

# %% [markdown]
# Here the model is built and tested on the same data, so the training and test data are the same.
#
# The red line in Figure 4 represents the R^2 of the training data. As alpha increases the R^2 decreases. Therefore, as alpha increases, the model performs worse on the training data
#
# The blue line represents the R^2 on the validation data. As the value for alpha increases, the R^2 increases and converges at a point.

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1> Question  #5): </h1>
#
# Perform Ridge regression. Calculate the R^2 using the polynomial features, use the training data to train the model and use the test data to test the model. The parameter alpha should be set to 10.
#
# </div>

# %%
# Performing Ridge regression, calculating R Squared using the polynomial features. We will use the train data to train the model and the test data to test the model. Alpha will be set to 10.

# Creating the polynomial features
pr2 = PolynomialFeatures(degree=2)

# Splitting the data
x_train_pr2 = pr2.fit_transform(x_train[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg','normalized-losses','symboling']])
x_test_pr2 = pr2.fit_transform(x_test[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg','normalized-losses','symboling']])

# Creating the Ridge regression object with alpha equal to 10
RidgeModel2 = Ridge(alpha=10)

# Fitting the model
RidgeModel2.fit(x_train_pr2, y_train)

# Generating a prediction
yhat2 = RidgeModel2.predict(x_test_pr2)

# Obtaining R Squared
r_squared_2 = RidgeModel2.score(x_test_pr2, y_test)
print('R Squared is: ', r_squared_2)
# Out:
# R Squared is:  0.5418576440207339

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# RigeModel = Ridge(alpha=10)
# RigeModel.fit(x_train_pr, y_train)
# RigeModel.score(x_test_pr, y_test)
#
# ```
#
# </details>

# %% [markdown]
# <h2 id="ref4">Part 4: Grid Search</h2>

# %% [markdown]
# The term alpha is a hyperparameter. Sklearn has the class <b>GridSearchCV</b> to make the process of finding the best hyperparameter simpler.

# %% [markdown]
# Let's import <b>GridSearchCV</b> from  the module <b>model_selection</b>.

# %%
# Importing needed library

from sklearn.model_selection import GridSearchCV

# %% [markdown]
# We create a dictionary of parameter values:

# %%
# Creating a dictionary with parameter values for alpha

parameters1= [{'alpha': [0.001,0.1,1, 10, 100, 1000, 10000, 100000, 100000]}]
parameters1
# Out:
# [{'alpha': [0.001, 0.1, 1, 10, 100, 1000, 10000, 100000, 100000]}]

# %% [markdown]
# Create a Ridge regression object:

# %%
# Creating a Ridge regression object

RR = Ridge()
RR
# Out:
# Ridge()

# %% [markdown]
# Create a ridge grid search object:

# %%
# Creating a Grid Search object

Grid1 = GridSearchCV(RR, parameters1, cv=4)

# %% [markdown]
# Fit the model:

# %%
# Fitting the model

Grid1.fit(x_data[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']], y_data)
# Out:
# GridSearchCV(cv=4, estimator=Ridge(),
#              param_grid=[{'alpha': [0.001, 0.1, 1, 10, 100, 1000, 10000, 100000,
#                                     100000]}])

# %% [markdown]
# The object finds the best parameter values on the validation data. We can obtain the estimator with the best parameters and assign it to the variable BestRR as follows:

# %%
# Obtaining the best parameter value

BestRR = Grid1.best_estimator_
BestRR
# Out:
# Ridge(alpha=10000)

# %% [markdown]
# We now test our model on the test data:

# %%
# Testing the model using the test data

BestRR.score(x_test[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']], y_test)
# Out:
# 0.841164983103615

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1> Question  #6): </h1>
# Perform a grid search to find the best alpha value and check if using feature scaling improves the model.
# </div>

# %%
# Performing Grid Search to find the best alpha value and use scaling to see if it makes a difference

# Importing neded libraries
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Ridge

# Creating pipeline
pipe = Pipeline([
    ('scale', StandardScaler()),
    ('ridge', Ridge())
])

# Defining the Parameter Grid
parameters2= [{'ridge__alpha': [0.001,0.1,1, 10, 100, 1000, 10000, 100000, 100000]}]

# Running the Grid Search
Grid2 = GridSearchCV(pipe, parameters2, cv=4)

# Fitting the model
Grid2.fit(x_data[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']], y_data)

# Printing results
print(f"Best Alpha: {Grid2.best_params_}")
print(f"Best Score: {Grid2.best_score_}")
# Out:
# Best Alpha: {'ridge__alpha': 100}
# Best Score: 0.702000556050028

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# x_scaled = scaler.fit_transform(x_data[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']])
#
# # Define parameter grid without 'normalize'
# parameters2 = [{'alpha': [0.001, 0.1, 1, 10, 100, 1000, 10000, 100000, 1000000]}]
#
# # Perform Grid Search
# Grid2 = GridSearchCV(Ridge(), parameters2, cv=4)
# Grid2.fit(x_scaled, y_data)
#
# # Best model
# best_ridge_model = Grid2.best_estimator_
# best_alpha = Grid2.best_params_['alpha']
# best_alpha
#
# ```
#
# </details>

# %% [markdown]
# **Note:** Although the unscaled model yielded a higher score (R Squared of 0.84) compared to the scaled model (R Squared of 0.7), standard best practices dictate selecting the **scaled version**. Feature scaling ensures that variables with larger magnitudes do not disproportionately influence the model, leading to better **generalization** and more reliable performance when applied to real-world, unseen data.

# %% [markdown]
# ### Thank you for completing this lab!
#
# ## Author
#
# <a href="https://www.linkedin.com/in/joseph-s-50398b136/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDA0101ENSkillsNetwork971-2022-01-01" target="_blank">Joseph Santarcangelo</a>
#
# ### Other Contributors
#
# <a href="https://www.linkedin.com/in/mahdi-noorian-58219234/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDA0101ENSkillsNetwork971-2022-01-01" target="_blank">Mahdi Noorian PhD</a>
#
# Bahare Talayian
#
# Eric Xiao
#
# Steven Dong
#
# Parizad
#
# Hima Vasudevan
#
# <a href="https://www.linkedin.com/in/fiorellawever/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDA0101ENSkillsNetwork971-2022-01-01" target="_blank">Fiorella Wenver</a>
#
# <a href="https:// https://www.linkedin.com/in/yi-leng-yao-84451275/ " target="_blank" >Yi Yao</a>.
#
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>
#
#
# <!--## Change Log
#
# | Date (YYYY-MM-DD) | Version | Changed By | Change Description                  |
# | ----------------- | ------- | ---------- | ----------------------------------- |
# | 2025-06-13        | 2.5     | Anita Verma| Updated Q6 due to deprecated normalize|
# | 2022-07-05        | 2.4     | Pooja      | Changed and added a new code        |
# | 2020-10-30        | 2.3     | Lakshmi    | Changed URL of csv                  |
# | 2020-10-05        | 2.2     | Lakshmi    | Removed unused library imports      |
# | 2020-09-14        | 2.1     | Lakshmi    | Made changes in OverFitting section |
# | 2020-08-27        | 2.0     | Lavanya    | Moved lab to course repo in GitLab  |
# --!>
#
# <hr>
